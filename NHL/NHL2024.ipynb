# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('SkaterSummary.xlsx')

# %%
df.head()
# Out:
#              Player    Season Team S/C Pos  GP  G  A   P  +/-  ...  PPG  PPP  \
# 0    Leon Draisaitl  20242025  EDM   L   C  10  6  4  10    0  ...    1    2
# 1  William Nylander  20242025  TOR   R   R  10  6  4  10    5  ...    1    2
# 2    Dylan Guenther  20242025  UTA   R   R  11  6  4  10    4  ...    2    5
# 3    Travis Konecny  20242025  PHI   R   R  10  5  5  10   -6  ...    3    4
# 4      Adrian Kempe  20242025  LAK   L   R  11  4  6  10    4  ...    1    2
#
#    SHG  SHP  OTG  GWG   S    S%  TOI/GP  FOW%
# 0    0    0    2    3  26  23.1   21:04  61.8
# 1    0    0    0    1  29  20.7   18:01  56.3
# 2    0    0    1    1  28  21.4   16:02    25
# 3    1    1    0    0  29  17.2   20:21  41.7
# 4    1    1    0    0  26  15.4   18:09    60
#
# [5 rows x 24 columns]

# %%
skate = df.copy()
skate.set_index('Player', inplace=True)

# %%
skate.head()
# Out:
#                     Season Team S/C Pos  GP  G  A   P  +/-  PIM  ...  PPG  \
# Player                                                           ...
# Leon Draisaitl    20242025  EDM   L   C  10  6  4  10    0   10  ...    1
# William Nylander  20242025  TOR   R   R  10  6  4  10    5    6  ...    1
# Dylan Guenther    20242025  UTA   R   R  11  6  4  10    4   10  ...    2
# Travis Konecny    20242025  PHI   R   R  10  5  5  10   -6   17  ...    3
# Adrian Kempe      20242025  LAK   L   R  11  4  6  10    4    6  ...    1
#
#                   PPP  SHG  SHP  OTG  GWG   S    S%  TOI/GP  FOW%
# Player
# Leon Draisaitl      2    0    0    2    3  26  23.1   21:04  61.8
# William Nylander    2    0    0    0    1  29  20.7   18:01  56.3
# Dylan Guenther      5    0    0    1    1  28  21.4   16:02    25
# Travis Konecny      4    1    1    0    0  29  17.2   20:21  41.7
# Adrian Kempe        2    1    1    0    0  26  15.4   18:09    60
#
# [5 rows x 23 columns]

# %%
skate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, Leon Draisaitl to Mason Appleton
# Data columns (total 23 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Season  50 non-null     int64
#  1   Team    50 non-null     object
#  2   S/C     50 non-null     object
#  3   Pos     50 non-null     object
#  4   GP      50 non-null     int64
#  5   G       50 non-null     int64
#  6   A       50 non-null     int64
#  7   P       50 non-null     int64
#  8   +/-     50 non-null     int64
#  9   PIM     50 non-null     int64
#  10  P/GP    50 non-null     float64
#  11  EVG     50 non-null     int64
#  12  EVP     50 non-null     int64
#  13  PPG     50 non-null     int64
#  14  PPP     50 non-null     int64
#  15  SHG     50 non-null     int64
#  16  SHP     50 non-null     int64
#  17  OTG     50 non-null     int64
#  18  GWG     50 non-null     int64
#  19  S       50 non-null     int64
#  20  S%      50 non-null     float64
#  21  TOI/GP  50 non-null     object
#  22  FOW%    50 non-null     object
# dtypes: float64(2), int64(16), object(5)
# memory usage: 9.4+ KB

# %%
skate['FOW%']
# Out:
# Player
# Leon Draisaitl       61.8
# William Nylander     56.3
# Dylan Guenther         25
# Travis Konecny       41.7
# Adrian Kempe           60
# Rasmus Andersson       --
# Connor McDavid         49
# Sidney Crosby        58.2
# Lucas Raymond          --
# Ross Colton          38.6
# Jordan Eberle          50
# Pavel Dorofeyev        --
# Alex Laferriere      14.3
# John Tavares         60.9
# Mats Zuccarello      69.2
# Nino Niederreiter    42.9
# Sean Monahan         51.9
# Brock Boeser         33.3
# J.T. Miller            60
# Brandon Montour        --
# Connor McMichael     61.1
# Matvei Michkov       58.3
# Nick Paul            38.9
# Alex Tuch              40
# Cole Perfetti        28.6
# Connor Bedard          30
# Victor Hedman          --
# Jordan Kyrou         42.9
# Mikhail Sergachev      --
# Shea Theodore          --
# Logan Stankoven      29.6
# Mike Matheson          --
# Rickard Rakell          0
# David Pastrnak         --
# Paul Cotter          45.5
# Kevin Fiala          28.6
# Troy Terry              0
# Alex DeBrincat       33.3
# Erik Haula             58
# Tyler Seguin         48.9
# Filip Forsberg          0
# Roope Hintz          48.3
# Auston Matthews        53
# Josh Norris          53.7
# Alexis Lafrenière      75
# JJ Peterka            100
# Ryan O'Reilly        51.4
# Sebastian Aho        55.7
# Zach Werenski          --
# Mason Appleton        100
# Name: FOW%, dtype: object

# %%
skate.isnull().sum()
# Out:
# Season    0
# Team      0
# S/C       0
# Pos       0
# GP        0
# G         0
# A         0
# P         0
# +/-       0
# PIM       0
# P/GP      0
# EVG       0
# EVP       0
# PPG       0
# PPP       0
# SHG       0
# SHP       0
# OTG       0
# GWG       0
# S         0
# S%        0
# TOI/GP    0
# FOW%      0
# dtype: int64
