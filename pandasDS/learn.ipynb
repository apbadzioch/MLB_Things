# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('data/data.xlsx')
df.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2        Unnamed: 3                    Name  \
# 0          X        NaN          K  ACTIVE - REGULAR        TEAGUE CHARLES E
# 1          X        NaN          K  ACTIVE - REGULAR        HELLER EMERSON E
# 2          X        NaN          K  ACTIVE - REGULAR     BRANDOM THOMAS M JR
# 3          X        NaN          K  ACTIVE - REGULAR  MCCORMICK WILLIAM C JR
# 4          X        NaN          K  ACTIVE - REGULAR         STALEY ROBERT E
#
#   branch Itnit     branch   rank Unnamed: 8 Unnamed: 9  ... Unnamed: 50  \
# 0            F  AIR FORCE  LTCOL        O05        NaN  ...         NaN
# 1            F  AIR FORCE  LTCOL        O05        NaN  ...         NaN
# 2            F  AIR FORCE    MAJ        O04        NaN  ...         NaN
# 3            F  AIR FORCE  LTCOL        O05        NaN  ...         NaN
# 4            F  AIR FORCE    MAJ        O04        NaN  ...         NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135795 entries, 0 to 135794
# Data columns (total 60 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    135795 non-null  object
#  1   Unnamed: 1    102776 non-null  object
#  2   Unnamed: 2    135795 non-null  object
#  3   Unnamed: 3    135650 non-null  object
#  4   Name          135795 non-null  object
#  5   branch Itnit  135795 non-null  object
#  6   branch        135795 non-null  object
#  7   rank          135795 non-null  object
#  8   Unnamed: 8    135795 non-null  object
#  9   Unnamed: 9    121103 non-null  object
#  10  Unnamed: 10   107057 non-null  object
#  11  Unnamed: 11   133524 non-null  object
#  12  Unnamed: 12   135795 non-null  object
#  13  city          133561 non-null  object
#  14  county        132475 non-null  object
#  15  Unnamed: 15   135778 non-null  object
#  16  state1        133562 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Unnamed: 1       33019
# Unnamed: 2           0
# Unnamed: 3         145
# Name                 0
# branch Itnit         0
# branch               0
# rank                 0
# Unnamed: 8           0
# Unnamed: 9       14692
# Unnamed: 10      28738
# Unnamed: 11       2271
# Unnamed: 12          0
# city              2234
# county            3320
# Unnamed: 15         17
# state1            2233
# state 2           2236
# Unnamed: 18          5
# Unnamed: 19      36199
# Unnamed: 20      36561
# Unnamed: 21        404
# Unnamed: 22         42
# Unnamed: 23          0
# Unnamed: 24          0
# Unnamed: 25     100598
# Unnamed: 26      90670
# Unnamed: 27      55711
# Unnamed: 28       4314
# Unnamed: 29       4420
# Unnamed: 30       4300
# Unnamed: 31      39686
# Unnamed: 32      13540
# Unnamed: 33        742
# Unnamed: 34       1172
# Unnamed: 35       4013
# Unnamed: 36        775
# Unnamed: 37      28184
# Unnamed: 38      33051
# Unnamed: 39      34562
# ...

# %%
df.shape
# Out:
# (135795, 60)
